# %%
import torch

# %%
C = torch.randn(27,2)

# %%
C[[0]]
# Out:
# tensor([[0.9375, 0.3672]])

# %%
X = torch.randn((32,3)).int()

# %%
C[X]
# Out:
# tensor([[[ 0.3262,  0.3682],
#          [ 0.9375,  0.3672],
#          [ 0.9375,  0.3672]],
#
#         [[ 0.9375,  0.3672],
#          [ 1.2441, -0.7334],
#          [ 0.9375,  0.3672]],
#
#         [[ 1.2441, -0.7334],
#          [ 0.9375,  0.3672],
#          [ 0.9375,  0.3672]],
#
#         [[ 0.9375,  0.3672],
#          [ 0.9375,  0.3672],
#          [ 0.3262,  0.3682]],
#
#         [[ 0.9375,  0.3672],
#          [ 1.2441, -0.7334],
#          [ 0.3262,  0.3682]],
#
#         [[-0.0410, -2.2413],
#          [ 0.9375,  0.3672],
#          [ 0.9375,  0.3672]],
#
#         [[ 0.9375,  0.3672],
#          [ 1.2441, -0.7334],
#          [ 0.9375,  0.3672]],
#
#         [[ 0.9375,  0.3672],
#          [ 0.9375,  0.3672],
#          [ 0.3262,  0.3682]],
#
#         [[ 0.9375,  0.3672],
#          [ 1.2441, -0.7334],
#          [ 1.2441, -0.7334]],
#
#         [[ 0.9375,  0.3672],
#          [ 0.3262,  0.3682],
#          [ 0.9375,  0.3672]],
#
#         [[ 0.9375,  0.3672],
# ...

# %%
# Out:
# tensor(0, dtype=torch.int32)
